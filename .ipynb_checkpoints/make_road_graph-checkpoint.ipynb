# %%
import os
import folium
import pandas as pd
import numpy as np
import networkx as nx

# %%
nodes = pd.read_csv('./node_data/node.csv')
links = pd.read_csv('./node_data/link.csv')
# Out:
# /var/folders/6s/5sc4hlbx0vv8cz2rd1gwn_4w0000gn/T/ipykernel_10176/3655025204.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   nodes = pd.read_csv('./node_data/node.csv')

# %%
nodes
# Out:
#         Unnamed: 0     NODE_ID  NODE_TYPE  NODE_NAME  TURN_P REMARK
# 0                0  1240094800        102   고덕동467-4       0    NaN  \
# 1                1  1240094900        101   고덕동465-7       0    NaN
# 2                2  1240095000        102     고덕동468       0    NaN
# 3                3  1240095100        101  고덕동353-27       0    NaN
# 4                4  1770084301        102        오꼬꼬       0    NaN
# ...            ...         ...        ...        ...     ...    ...
# 201748      201748  2440328800        106       기흥IC       0    NaN
# 201749      201749  2440328900        106       기흥IC       0    NaN
# 201750      201750  2440329100        101       기흥IC       0    NaN
# 201751      201751  2440042400        106      기흥TG앞       0    NaN
# 201752      201752  2440329000        106      기흥TG앞       0    NaN
#
#           latitude  longitude
# 0       130.825185  34.460270
# 1       130.826354  34.460245
# 2       130.825275  34.461248
# ...

# %%
nodes = nodes[['NODE_ID', 'NODE_NAME', 'latitude', 'longitude']]

# %%
links
# Out:
#         Unnamed: 0     LINK_ID      F_NODE      T_NODE  LANES  ROAD_RANK
# 0                0  2560030400  2560013900  2560014500      2        103  \
# 1                1  2560038800  2560018000  2560018100      2        107
# 2                2  2560038900  2560017900  2560018400      2        103
# 3                3  2560039000  2560018400  2560017900      2        103
# 4                4  2560039100  2560018200  2560018500      3        107
# ...            ...         ...         ...         ...    ...        ...
# 542710      542710  2560028904  2560013102  2560013101      1        105
# 542711      542711  2560035200  2560016600  2560016400      3        107
# 542712      542712  2020024500  2020009800  2020009200      4        107
# 542713      542713  2020036000  2020013200  2020013000      1        107
# 542714      542714  2220055100  2220040900  2220041000      1        107
#
#         ROAD_TYPE ROAD_NO ROAD_NAME  ROAD_USE  MULTI_LINK  CONNECT  MAX_SPD
# ...

# %%
links = links[['LINK_ID', 'F_NODE', 'T_NODE', 'LENGTH']]

# %%
links
# Out:
#            LINK_ID      F_NODE      T_NODE      LENGTH
# 0       2560030400  2560013900  2560014500  901.589333
# 1       2560038800  2560018000  2560018100  118.955354
# 2       2560038900  2560017900  2560018400  123.251630
# 3       2560039000  2560018400  2560017900  123.623122
# 4       2560039100  2560018200  2560018500  128.922824
# ...            ...         ...         ...         ...
# 542710  2560028904  2560013102  2560013101  979.523801
# 542711  2560035200  2560016600  2560016400  258.670733
# 542712  2020024500  2020009800  2020009200  101.933283
# 542713  2020036000  2020013200  2020013000   40.006728
# 542714  2220055100  2220040900  2220041000  121.806008
#
# [542715 rows x 4 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 3
#       1 import matplotlib.pyplot as plt
#       2 # G = nx.cubical_graph()
# ----> 3 nx.draw(G)   # default spring_layout
#       4 # subax2 = plt.subplot(122)
#       5 # nx.draw(G, pos=nx.circular_layout(G), node_color='r', edge_color='b')
#
# File ~/anaconda3/envs/baedal/lib/python3.11/site-packages/networkx/drawing/nx_pylab.py:121, in draw(G, pos, ax, **kwds)
#     118 if "with_labels" not in kwds:
#     119     kwds["with_labels"] = "labels" in kwds
# --> 121 draw_networkx(G, pos=pos, ax=ax, **kwds)
#     122 ax.set_axis_off()
#     123 plt.draw_if_interactive()
#
# File ~/anaconda3/envs/baedal/lib/python3.11/site-packages/networkx/drawing/nx_pylab.py:301, in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     298 label_kwds = {k: v for k, v in kwds.items() if k in valid_label_kwds}
# ...
